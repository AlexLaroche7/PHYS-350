# %% [markdown]
# ## PHYS 350 - Assignment 1 - Bonus

# %%
import PHYS350PS1 as ps1

# %%
ps1.point_charge_ring(n=50,m=34,q=1)
# Out:
# E(0,0) = 0.3199600858054342 i + 0.23246460960189227 j

# %% [markdown]
# $n=50, m=34, q=1C, r=1m,$ for example.

# %%
ps1.point_charge_ring(n=13,m=12,q=1)
# Out:
# E(0,0) = 1.3877787807814457e-17 i + 0.08333333333333348 j

# %% [markdown]
# $n=13, m=12, q=1C, r=1m, \mathbf{E}(0,0) = 1.388\times10^{-17} \hat{x} + 0.083 \hat{y}.$ The force felt by Q, neglecting $4\pi\epsilon_0,$ is therefore $F = qQ/r^2 = Q/m,$ in the $+\hat{y}$ direction. This is equivalent to a negative $q/m$ charge in the missing slot.

# %%
ps1.center_charge_ring(1001)

# %% [markdown]
# $Q=1C,q=1C,r=1m.$ Net force up to $n=1001.$ The charges are placed, beginning from the 12 o'clock position, in a counter clockwise fashion. The force is solely in the $+\hat{x}$ direction. Units are neglecting $4\pi\epsilon_0.$ It makes sense that the force in the $+\hat{y}$ direction is zero as the point charges are symmetric about the $x$ axis and cancel out. Furthermore, the point charges, however many there are, contain the same amount of charge which results in a constant force in the $+\hat{x}$ direction.
